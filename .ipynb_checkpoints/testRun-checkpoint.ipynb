# %%
import requests
import pickle
import pprint
import time
from datetime import datetime
import plotly.express as px
import plotly.graph_objs as go

# %%
from fundamentalScripts import accessing_endpoints_loop,dataExtraction,percent_Change,dataTransformation,stockViz

# %%
stockViz(dataTransformation(dataExtraction(accessing_endpoints_loop('V'))))

# %%
ticker_symbols = ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'GOOG', 'FB', 'JNJ', 'V', 'PG', 'JPM','XOM', 'VZ', 'T', 'HD', 'UNH', 'MA', 'INTC', 'CVX', 'WFC', 'PFE','CSCO', 'DIS', 'PEP', 'BAC', 'BA', 'MRK', 'NKE', 'KO', 'GE', 'MCD','CAT', 'DWDP', 'MMM', 'IBM', 'WMT', 'UNP', 'AXP', 'VRSN', 'UPS', 'ORCL','CHTR', 'TMO', 'ADBE', 'DOW', 'LLY', 'ACN', 'ABT', 'NVDA', 'AVGO', 'HON','TXN', 'NEE', 'INTU', 'MO', 'MDLZ', 'PM', 'TATAMOTORS', 'VOD', 'MMC', 'VFC','ADP', 'ITW', 'ROP', 'CELG', 'LMT', 'BLK', 'BKNG', 'WBA', 'SBUX', 'DUK','EXC', 'LOW', 'AMT', 'SO', 'PNC', 'EMR', 'HUM', 'PPG', 'RTN', 'LRCX','CVS', 'PPL', 'MRO', 'AEP', 'MS', 'D', 'CAG', 'ED', 'AIG', 'CMCSA']

run_time_list = []

for i in ticker_symbols:

  start_time = time.time()

  stockViz(dataTransformation(dataExtraction(accessing_endpoints_loop(i))))

  end_time = time.time()

  run_time = (end_time)-(start_time)

  run_time_list.append(run_time)

print("The average runtime is:")
print(sum(run_time_list)/len(ticker_symbols))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 5>()
#       5 for i in ticker_symbols:
#       7   start_time = time.time()
# ----> 9   stockViz(dataTransformation(dataExtraction(accessing_endpoints_loop(i))))
#      11   end_time = time.time()
#      13   run_time = (end_time)-(start_time)
#
# File ~\Desktop\CloudDB-project\fundamentalScripts.py:38, in dataExtraction(data)
#      36 def dataExtraction(data):
# ---> 38     company_monthly_data = data[0]['Monthly Time Series']
#      40     dateString = list(company_monthly_data.keys())
#      42     monthly_closing_price = []
#
# KeyError: 'Monthly Time Series'
